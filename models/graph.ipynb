# %%
import matplotlib.pyplot as plt

# %%
# MNIST
dataset = 'mnist'
focus = [0.947, 0.9628, 0.9718, 0.9753, 0.9753, 0.978, 0.9777, 0.9783, 0.9791, 0.9795, 0.9799, 0.9795, 0.9797, 0.9796, 0.9795, 0.9794, 0.9795, 0.9795, 0.9796, 0.9796]
corner = [0.8001, 0.833, 0.8445, 0.8508, 0.8561, 0.8594, 0.8614, 0.8628, 0.8634, 0.8649, 0.8652, 0.8653, 0.8648, 0.8646, 0.8646, 0.8647, 0.8648, 0.8648, 0.8649, 0.8648]
attention = [0] * 20

# %%
# FashionMNIST
dataset = 'fashionmnist'
focus = [0.7897, 0.8187, 0.8333, 0.8424, 0.8468, 0.8524, 0.8548, 0.8556, 0.8575, 0.8583, 0.8598, 0.861, 0.8607, 0.8609, 0.8612, 0.861, 0.8608, 0.8613, 0.8608, 0.8611]
corner = [0.6364, 0.674, 0.6924, 0.7036, 0.7091, 0.7133, 0.7153, 0.7158, 0.7169, 0.7167, 0.7172, 0.7173, 0.7183, 0.7187, 0.7191, 0.7193, 0.7197, 0.7198, 0.72, 0.7201]
attention = [0] * 20

# %%
# CIFIR10
dataset = 'cifar10'
focus = [0.3573, 0.4265, 0.4734, 0.4693, 0.4897, 0.4832, 0.4907, 0.4971, 0.5054, 0.5069, 0.5144, 0.5157, 0.5156, 0.5169, 0.5182, 0.5178, 0.5182, 0.5185, 0.5183, 0.5188]
corner = [0.2671, 0.2949, 0.3166, 0.3266, 0.3299, 0.3323, 0.3348, 0.3355, 0.3366, 0.3383, 0.339, 0.3397, 0.3402, 0.3402, 0.341, 0.3409, 0.3415, 0.3409, 0.3409, 0.3409]
attention = [0.6296, 0.6918, 0.7156, 0.7402, 0.7562, 0.7636, 0.7726, 0.7775, 0.7779, 0.7818, 0.7818, 0.7831, 0.784, 0.7852, 0.785, 0.784, 0.7837, 0.7843, 0.7857, 0.7848]

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, 20 + 1), focus, marker='o', label='Focus Model')
plt.plot(range(1, 20 + 1), corner, marker='o', label='Corner Model')
if attention[0] != 0:
    plt.plot(range(1, 20 + 1), attention, marker='o', label='Attention Model')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Over Epochs (' + dataset + ")")
plt.grid(True)
plt.legend()
plt.savefig('focus_accuracy_plot.png')
plt.show()
